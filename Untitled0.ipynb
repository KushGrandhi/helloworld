# %% [markdown]
# <a href="https://colab.research.google.com/github/tinyfiddle4864/helloworld/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])

# %%
model.compile(optimizer="sgd",loss="mean_squared_error")

# %%
x=np.array([-1.0,0.0,1.0,2.0,3.0,4.0],dtype = float)

# %%
print(x)
# Out:
# [-1.  0.  1.  2.  3.  4.]

# %%
y = np.array([-2.0,1.0,4.0,7.0,10.0,13.0])
print(y)
# Out:
# [-2.  1.  4.  7. 10. 13.]

# %%
model.fit(x,y,epochs=1000)
# Out:
# Train on 6 samples
# Epoch 1/1000
# 6/6 [==============================] - 0s 8ms/sample - loss: 27.4660
# Epoch 2/1000
# 6/6 [==============================] - 0s 344us/sample - loss: 21.6204
# Epoch 3/1000
# 6/6 [==============================] - 0s 290us/sample - loss: 17.0212
# Epoch 4/1000
# 6/6 [==============================] - 0s 296us/sample - loss: 13.4025
# Epoch 5/1000
# 6/6 [==============================] - 0s 213us/sample - loss: 10.5553
# Epoch 6/1000
# 6/6 [==============================] - 0s 303us/sample - loss: 8.3150
# Epoch 7/1000
# 6/6 [==============================] - 0s 274us/sample - loss: 6.5522
# Epoch 8/1000
# 6/6 [==============================] - 0s 316us/sample - loss: 5.1651
# Epoch 9/1000
# 6/6 [==============================] - 0s 216us/sample - loss: 4.0737
# Epoch 10/1000
# 6/6 [==============================] - 0s 421us/sample - loss: 3.2147
# Epoch 11/1000
# 6/6 [==============================] - 0s 269us/sample - loss: 2.5387
# Epoch 12/1000
# ...

# %%
print(model.predict([19.0]))
# Out:
# [[58.00007]]
